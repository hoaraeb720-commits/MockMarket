# %%
# !uv pip install "pymongo[srv]"
# Out:
# Resolved 2 packages in 264ms
# Prepared 1 package in 134ms
# Installed 2 packages in 22ms
#  + dnspython==2.8.0
#  + pymongo==4.16.0
# warning: The package `pymongo==4.16.0` does not have an extra named `srv`

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://mockmarket:mockmarket@mock-market-cluster.wkndkr1.mongodb.net/?appName=mock-market-cluster"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
client["mockmarket"]["users"].insert_many([{
    "username": "aowang",
    "password_hash": "password"
}])
# Out:
# InsertManyResult([ObjectId('69a0e5f33d5b46d8860dc952')], acknowledged=True)
